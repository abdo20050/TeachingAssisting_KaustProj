# %%
pip install xformers
# Out:
# WARNING: Ignoring invalid distribution -orch (/home/abdulna/miniconda3/envs/myenv2/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/home/abdulna/miniconda3/envs/myenv2/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import torch
src_text = [
    """ PG&E stated it scheduled the blackouts in response to forecasts for high winds amid dry conditions. The aim is to reduce the risk of wildfires. Nearly 800 thousand customers were scheduled to be affected by the shutoffs which were expected to last through at least midday tomorrow."""
]

model_name = './model/'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
# Out:
# generator done!!!

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 tokenizer = tokenizer( padding='max_length', truncation=True)
#
# File ~/miniconda3/envs/myenv2/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2571, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2569 all_kwargs.update(kwargs)
#    2570 if text is None and text_target is None:
# -> 2571     raise ValueError("You need to specify either `text` or `text_target`.")
#    2572 if text is not None:
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("TanveerAman/AMI-Corpus-Text-Summarization")
test_texts, test_labels = dataset['test']['Dialogue'][:], dataset['test']['Summaries'][:]

# %%
batch = tokenizer.prepare_seq2seq_batch(test_texts[0], truncation=True, padding='longest', return_tensors="pt").to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
# Out:
# 36043

# %%
txt = tokenizer( test_texts[0],padding='max_length', truncation=True)

# %%
generator(txt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 generator(txt)
#
# File ~/miniconda3/envs/myenv2/lib/python3.9/site-packages/transformers/pipelines/text2text_generation.py:265, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     241 def __call__(self, *args, **kwargs):
#     242     r"""
#     243     Summarize the text(s) given as inputs.
#     244
#    (...)
#     263           ids of the summary.
#     264     """
# --> 265     return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv2/lib/python3.9/site-packages/transformers/pipelines/text2text_generation.py:165, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     136 def __call__(self, *args, **kwargs):
#     137     r"""
#     138     Generate the output text(s) using text(s) given as inputs.
#     139
#    (...)
# ...

# %%
iter = tex
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (12031 > 1024). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 generator(test_texts[0])
#
# File ~/miniconda3/envs/myenv2/lib/python3.9/site-packages/transformers/pipelines/text2text_generation.py:265, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     241 def __call__(self, *args, **kwargs):
#     242     r"""
#     243     Summarize the text(s) given as inputs.
#     244
#    (...)
#     263           ids of the summary.
#     264     """
# --> 265     return super().__call__(*args, **kwargs)
#
# ...
