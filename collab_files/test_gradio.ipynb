# %%
import torch

# %%
import torch

if torch.cuda.is_available():
    print("CUDA GPU is available!")
else:
    print("No CUDA GPU found.")

# %%
import gradio as gr
import os
os?
# from run_whisper import speetch_to_txt
blocks = gr.Blocks()

with blocks as demo:
    drop = gr.Audio(source="upload", type="filepath", label="Drop your audio file here!")
    record = gr.Audio(source="microphone", label="Record!")

    with gr.Row():
        btn1 = gr.Button("Use Uploaded Audio")
        btn2 = gr.Button("Use Recorded Audio.")

    def generate(input):
        print(input)
        # output = speetch_to_txt(input) #Use whisper here
        output = input #GPT to summarize here
        output = os.listdir('../') #Microsoft translation here
        return output

    output1 = gr.Textbox(label="Output")

    btn1.click(generate, drop, output1)
    btn2.click(generate, record, output1)
demo?
demo.launch(share = True )
print(demo.port())
# Out:
# Running on local URL:  http://127.0.0.1:7862
# Running on public URL: https://ca773de390364efae9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ca773de390364efae9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 28
#      26 get_ipython().run_line_magic('pinfo', 'demo')
#      27 demo.launch(share = True )
# ---> 28 print(demo.port())
#
# AttributeError: 'Blocks' object has no attribute 'port'
